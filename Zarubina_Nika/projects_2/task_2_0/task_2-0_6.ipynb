# %%
f = open("C:\\Users\\User\\Downloads\\Zarubina_Nika\\projects_2\\task_2_0\\output.txt", "w", encoding="utf-8")
print("Я Ника Зарубина. Я люблю розовый цвет и носить смешные шапки, а ещё я хипстер ", file=f)
f.close()
