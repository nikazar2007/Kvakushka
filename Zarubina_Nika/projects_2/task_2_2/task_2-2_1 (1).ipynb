# %%
Course_name = 'Курс Успеха'
Current_stage = 5
Completed_tasks = 100
print(f"Название курса: {Course_name}, номер текущего курса: {Current_stage}, количество выполненных задач: {Completed_tasks}")
# Out:
# Название курса: Курс Успеха, номер текущего курса: 5, количество выполненных задач: 100
