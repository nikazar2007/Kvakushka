# %%
device_name = 'Настольная центрифуга'
number = 'V-52'
device_status = 'Исправен'
number_of_pieces = 3
print(f'Название прибора\t{device_name}\nИнвентарный номер\t{number}\nСостояние\t\t{device_status}\nКоличество\t\t{number_of_pieces}')
# Out:
# Название прибора	Настольная центрифуга
# Инвентарный номер	V-52
# Состояние		Исправен
# Количество		3
