# %%
f = open("C:\\Users\\User\\Downloads\\Zarubina_Nika\\projects_2\\task_2_2\\inventory.txt", "w", encoding="utf-8")
reagent_name = input("Название реагента:")
quantity = input ("количество (целое число):")
print(f"Реактив {reagent_name} поступил на склад в количестве {quantity} шт.", file=f)
f.close()
