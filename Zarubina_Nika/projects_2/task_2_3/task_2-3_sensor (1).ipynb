# %%
name = input("Имя оператора")
pressure = input("Текущее давление (Па)")
with open("C:\\Users\\User\\Downloads\\sensor_log.txt", "w", encoding="utf-8") as log:
    log.write(f"ОПЕРАТОР\tЗНАЧЕНИЕ\n\n{name}\t{pressure} (Па)")
print("Данные успешно сохранены в sensor_log.txt")
