# %%
proteins = float(input(" массу белков (г): "))
fats = float(input("Массу жиров (г): "))
carbs = float(input("Массу углеводов (г): "))

# Расчёт калорийности
calories = proteins * 4 + fats * 9 + carbs * 4

# Вывод результата
print(f"Калорийность продукта: {calories} ккал")
