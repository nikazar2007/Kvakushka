# %%
obiom = float(input("Объем раствора (мл): "))
salt_mass = obiom * 0.009
water_obiom = obiom
with open("C:\\Users\\User\\Downloads\\recipe.txt", "w", encoding="utf-8") as f:
    f.write(f"ОТЧЁТ ПО ПРИГОТОВЛЕНИЮ:\n-----------------------\nОбщий объем: {obiom} мл\nМасса соли: {salt_mass:.2f} г\nОбъем воды: {water_obiom} мл")
print("Рецепт сохранен в файл recipe.txt")
