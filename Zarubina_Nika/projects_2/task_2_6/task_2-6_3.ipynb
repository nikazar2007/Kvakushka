# %%
donor = input("Группа крови донора (0, A, B, AB): ").strip().upper()
recipient = input("Группа крови пациента (0, A, B, AB): ").strip().upper()
if donor == recipient or donor == "0" or donor == "O":
    print("Переливание возможно")
else:
    print("Переливание невозможно")
# Out:
# Группа крови донора (0, A, B, AB):  0
# Группа крови пациента (0, A, B, AB):  A
# Переливание возможно
