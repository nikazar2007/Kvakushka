# %%
date = "21.02.2026"
files = ["seq1", "seq2", "seq3", "seq4"]
for name in files:
    new_name = f"{name}_{date}.fasta"
    print(new_name)
# Out:
# seq1_21.02.2026.fasta
# seq2_21.02.2026.fasta
# seq3_21.02.2026.fasta
# seq4_21.02.2026.fasta
