# %%
A = float(input("Введите число A: "))
B = float(input("Введите число B: "))
C = float(input("Введите число C: "))
D = float(input("Введите число D: "))
sum_ = A + B + C + D
avg = sum_ / 4
print("Среднее арифметическое:", avg)
# Out:
# Введите число A:  6
# Введите число B:  9
# Введите число C:  10
# Введите число D:  8
# Среднее арифметическое: 8.25
