# %%
array = [64, 34, 25, 12, 22, 11, 90]
n = len(array)
sum_ = 0
i = 0
while i < n:
    if array[i] % 2 != 0:   
        sum_ = sum_ + array[i]
    i = i + 1
print("Сумма нечётных элементов массива:", sum_)
# Out:
# Сумма нечётных элементов массива: 36
