# %%
import pandas as pd
df = pd.read_csv('wild_boars.csv')
print("Длинна клыков:")
print(df['tusk_length_cm'])
# Out:
# Длинна клыков:
# 0       8.9
# 1       2.0
# 2      15.4
# 3      12.5
# 4       9.8
#        ...
# 195    14.7
# 196     1.8
# 197     7.0
# 198     2.7
# 199     0.0
# Name: tusk_length_cm, Length: 200, dtype: float64
