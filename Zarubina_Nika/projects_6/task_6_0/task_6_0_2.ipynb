# %%
import pandas as pd
df = pd.read_csv('wild_boars.csv')
averages = df.mean(numeric_only=True)  # считаем только числа
averages.to_csv('average_values.csv')
print("Средние значения сохранены в файл 'average_values.csv'")
# Out:
# Средние значения сохранены в файл 'average_values.csv'
