# %%
import pandas as pd
df = pd.read_csv('wild_boars.csv')
medians = df.median(numeric_only=True)
medians.to_csv('median_values.csv')
print("Медианные значения сохранены в файл 'median_values.csv'")
# Out:
# Медианные значения сохранены в файл 'median_values.csv'
