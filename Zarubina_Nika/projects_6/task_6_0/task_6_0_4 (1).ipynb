# %%
import pandas as pd
df = pd.read_csv('wild_boars.csv')
modes = df.mode().iloc[0] 
modes.to_csv('mode_values.csv')
print("Модальные значения сохранены в файл 'mode_values.csv'")
# Out:
# Модальные значения сохранены в файл 'mode_values.csv'
