# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 4
#       2 df = pd.read_csv('wild_boars.csv')
#       3 percentiles = [25, 50, 75, 90, 95, 100]
# ----> 4 result = df.select_dtypes(include=['number']).describe(percentiles=percentiles)
#       5 result.to_csv('percentiles.csv')
#       6 print(result)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:12041, in NDFrame.describe(self, percentiles, include, exclude)
#   11799 @final
#   11800 def describe(
#   11801     self,
#    (...)  11804     exclude=None,
#   11805 ) -> Self:
#   11806     """
#   11807     Generate descriptive statistics.
#   11808
#    (...)  12039     max            NaN      3.0
#   12040     """
# > 12041     return describe_ndframe(
#   12042         obj=self,
#   12043         include=include,
#   12044         exclude=exclude,
#   12045         percentiles=percentiles,
# ...
